# %%
import pandas as pd

# %%
df_city = pd.read_csv('weather_file.csv')
df_city
# Out:
#               City    Lat    Long  Max_temp  Humidity  Cloudiness  Wind_Speed  \
# 0            kapaa  22.08 -159.32     80.60        69          20       10.29
# 1         ajdabiya  30.76   20.23     56.93        50           0       10.22
# 2         tasiilaq  65.61  -37.64     17.60        92          14        2.24
# 3        busselton -33.65  115.33     64.00        74          25        3.00
# 4          ushuaia -54.80  -68.30     55.40        37          20        9.17
# ..             ...    ...     ...       ...       ...         ...         ...
# 558        oistins  13.07  -59.53     77.00        88          75        4.70
# 559        ipojuca  -8.40  -35.06     78.80        61          75       11.41
# 560    bandarbeyla   9.49   50.81     73.90        81          59       21.14
# 561      stornoway  58.21   -6.39     34.00        80          40        9.17
# 562  san miguelito   9.03  -79.50     82.40        88          40       11.41
#
#     Country        Date
# ...

# %%
#df_city.index.names = ["City_ID"]

# df_city['City_ID'] = df_city.index
df_city.insert(0, 'City_ID', df_city.index)

df_city.reset_index(drop=True, inplace=True)
df_city.head()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-86-b400b52a72b6> in <module>
#       2
#       3 # df_city['City_ID'] = df_city.index
# ----> 4 df_city.insert(0, 'City_ID', df_city.index)
#       5
#       6 df_city.reset_index(drop=True, inplace=True)
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/frame.py in insert(self, loc, column, value, allow_duplicates)
#    3622         self._ensure_valid_index(value)
#    3623         value = self._sanitize_column(column, value, broadcast=False)
# -> 3624         self._mgr.insert(loc, column, value, allow_duplicates=allow_duplicates)
#    3625
#    3626     def assign(self, **kwargs) -> "DataFrame":
#
# ~/opt/anaconda3/lib/python3.8/site-packages/pandas/core/internals/managers.py in insert(self, loc, item, value, allow_duplicates)
#    1175         if not allow_duplicates and item in self.items:
# ...

# %%
renamed_df=df_city.rename(columns={"Wind_Speed": "Wind Speed"})
renamed_df
# Out:
#      City_ID           City    Lat    Long  Max_temp  Humidity  Cloudiness  \
# 0          0          kapaa  22.08 -159.32     80.60        69          20
# 1          1       ajdabiya  30.76   20.23     56.93        50           0
# 2          2       tasiilaq  65.61  -37.64     17.60        92          14
# 3          3      busselton -33.65  115.33     64.00        74          25
# 4          4        ushuaia -54.80  -68.30     55.40        37          20
# ..       ...            ...    ...     ...       ...       ...         ...
# 558      558        oistins  13.07  -59.53     77.00        88          75
# 559      559        ipojuca  -8.40  -35.06     78.80        61          75
# 560      560    bandarbeyla   9.49   50.81     73.90        81          59
# 561      561      stornoway  58.21   -6.39     34.00        80          40
# 562      562  san miguelito   9.03  -79.50     82.40        88          40
#
#      Wind Speed Country        Date
# ...

# %%
# renamed_df.to_html(index=False, classes=["table","table-striped"])

# %%
# cleaned_table=table.replace('\n', '')
# cleaned_table
# Out:
# '<table border="1" class="dataframe table table-striped">  <thead>    <tr style="text-align: right;">      <th>City_ID</th>      <th>City</th>      <th>Lat</th>      <th>Long</th>      <th>Max_temp</th>      <th>Humidity</th>      <th>Cloudiness</th>      <th>Wind Speed</th>      <th>Country</th>      <th>Date</th>    </tr>  </thead>  <tbody>    <tr>      <td>0</td>      <td>kapaa</td>      <td>22.08</td>      <td>-159.32</td>      <td>80.60</td>      <td>69</td>      <td>20</td>      <td>10.29</td>      <td>US</td>      <td>1609278711</td>    </tr>    <tr>      <td>1</td>      <td>ajdabiya</td>      <td>30.76</td>      <td>20.23</td>      <td>56.93</td>      <td>50</td>      <td>0</td>      <td>10.22</td>      <td>LY</td>      <td>1609278980</td>    </tr>    <tr>      <td>2</td>      <td>tasiilaq</td>      <td>65.61</td>      <td>-37.64</td>      <td>17.60</td>      <td>92</td>      <td>14</td>      <td>2.24</td>      <td>GL</td>      <td>1609278981</td>    </tr>    <tr>      <td>3<
# ...

# %%
renamed_df.to_html('cleaned_table.html',index=False, classes=["table","table-striped"])

# %%
# !open cleaned_table.html
